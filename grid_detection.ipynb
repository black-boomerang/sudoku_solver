# %%
import os
import warnings

import cv2 as cv

from grid_detection import LineType, detect_grid
from utils import show_image

warnings.filterwarnings('ignore')

# %%
image = cv.imread('sudoku_dataset/datasets/v2_test/image1024.jpg')
h_lines, v_lines = detect_grid(image, show_steps=True, bin_threshold=1.5)

# %%
image_copy = image.copy()

for line in v_lines + h_lines:
    x1, y1, x2, y2 = line.x1, line.y1, line.x2, line.y2
    if line.line_type == LineType.HORIZONTAL:
        if line.x1 > line.x2:
            x1 = line.x1 + 1000
            x2 = line.x2 - 1000
        else:
            x1 = line.x1 - 1000
            x2 = line.x2 + 1000
    else:
        if line.y1 > line.y2:
            y1 = line.y1 + 1000
            y2 = line.y2 - 1000
        else:
            y1 = line.y1 - 1000
            y2 = line.y2 + 1000

    cv.line(image_copy, (x1, y1), (x2, y2), (255, 0, 0), 2)

show_image(image_copy, 'Результат детекции')

# %%
len(v_lines)

# %%
from cell_cutting import get_cells
import os
import cv2 as cv

all_num = 0
true_num = 0
for image_name in os.listdir(r'sudoku_dataset\images'):
    if image_name.endswith('jpg'):
        print(image_name)
        all_num += 1
        image = cv.imread(os.path.join(r'sudoku_dataset\images', image_name))
        p = len(list(get_cells(image)))
        print(p)
        if p == 81:
            true_num += 1
# Out:
# image1.jpg
# 81
# image10.jpg
# 81
# image100.jpg
# 81
# image1000.jpg
# 81
# image1001.jpg
# 81
# image1003.jpg
# 2
# image1004.jpg
# 72
# image1005.jpg
# 35
# image1006.jpg
# 81
# image1007.jpg
# 81
# image1008.jpg
# 18
# image1009.jpg
# 24
# image101.jpg
# 81
# image1011.jpg
# 18
# image1014.jpg
# 81
# image1019.jpg
# 81
# image102.jpg
# 81
# image1020.jpg
# 45
# image1022.jpg
# 0
# image1024.jpg
# 81
# image103.jpg
# 81
# image1031.jpg
# 81
# image1036.jpg
# 12
# image1038.jpg
# 81
# image1039.jpg
# 81
# image104.jpg
# 81
# image1040.jpg
# 81
# image1041.jpg
# 81
# image1043.jpg
# 0
# image1045.jpg
# 0
# image1048.jpg
# 81
# image1049.jpg
# 0
# image105.jpg
# 81
# image1050.jpg
# 81
# image1055.jpg
# 35
# image1059.jpg
# 81
# image106.jpg
# 81
# image1062.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 7>()
#      10 all_num += 1
#      11 image = cv.imread(os.path.join(r'sudoku_dataset\images', image_name))
# ---> 12 p = len(list(get_cells(image)))
#      13 print(p)
#      14 if p == 81:
#
# File E:\Homework\sudoku_solver\cell_cutting.py:27, in get_cells(image, out_image_side, bin_threshold)
#      24 def get_cells(image: np.ndarray, out_image_side: int = 32, bin_threshold: float = 2) -> Generator[
#      25     np.ndarray, None, None]:
#      26     for bin_threshold in np.linspace(0.5, 4.0, 8):
# ---> 27         h_lines, v_lines = detect_grid(image, bin_threshold=bin_threshold)
#      28         if len(h_lines) == 10 and len(v_lines) == 10:
#      29             break
#
# File E:\Homework\sudoku_solver\grid_detection.py:140, in detect_grid(image, show_steps, bin_threshold)
#     137     show_image(binarized_image, 'Препроцессинг')
#     139 # вероятностное преобразование Хафа
# --> 140 lines_infos = hough_transform(binarized_image)
#     141 if show_steps:
#     142     show_image_with_lines(image, lines_infos, 'Вероятностное преобразование Хафа')
#
# File E:\Homework\sudoku_solver\grid_detection.py:59, in hough_transform(image)
#      56 def hough_transform(image: np.ndarray) -> List[LineInfo]:
#      57     edges = cv.Canny(image, 0, 15, apertureSize=3)
# ---> 59     segments = cv.HoughLinesP(edges, 2, np.pi / 1200, 130, minLineLength=30, maxLineGap=10).squeeze()
#      60     lines_infos = []
#      61     for segment in segments:
#
# KeyboardInterrupt:

# %%
true_num / all_num
